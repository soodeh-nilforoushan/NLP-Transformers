# %% [markdown]
# <a href="https://colab.research.google.com/github/soodeh-nilforoushan/NLP-Transformers/blob/main/Fine_Tuning_Sentiment_Custom_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers datasets
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.28.0)
# Requirement already satisfied: datasets in /usr/local/lib/python3.10/dist-packages (2.14.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.12.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.16.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.13.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.1)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (9.0.0)
# Requirement already satisfied: dill<0.3.8,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.3.7)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (1.5.3)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets) (3.3.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.10/dist-packages (from datasets) (0.70.15)
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.8.5)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (3.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.11.0->transformers) (4.7.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2023.7.22)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2023.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->datasets) (1.16.0)

# %%
# !wget -nc https://lazyprogrammer.me/course_files/AirlineTweets.csv
# Out:
# File ‘AirlineTweets.csv’ already there; not retrieving.

# %%
from transformers import AutoTokenizer
from datasets import load_dataset
import numpy as np
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt

import torch
from sklearn.metrics import f1_score,accuracy_score, confusion_matrix
from sklearn.model_selection import train_test_split

# %%
df_=pd.read_csv("AirlineTweets.csv")

# %%
df_.head()
# Out:
#              tweet_id airline_sentiment  airline_sentiment_confidence  \
# 0  570306133677760513           neutral                        1.0000
# 1  570301130888122368          positive                        0.3486
# 2  570301083672813571           neutral                        0.6837
# 3  570301031407624196          negative                        1.0000
# 4  570300817074462722          negative                        1.0000
#
#   negativereason  negativereason_confidence         airline  \
# 0            NaN                        NaN  Virgin America
# 1            NaN                     0.0000  Virgin America
# 2            NaN                        NaN  Virgin America
# 3     Bad Flight                     0.7033  Virgin America
# 4     Can't Tell                     1.0000  Virgin America
#
#   airline_sentiment_gold        name negativereason_gold  retweet_count  \
# 0                    NaN     cairdin                 NaN              0
# 1                    NaN    jnardino                 NaN              0
# 2                    NaN  yvonnalynn                 NaN              0
# 3                    NaN    jnardino                 NaN              0
# 4                    NaN    jnardino                 NaN              0
#
#                                                 text tweet_coord  \
# 0                @VirginAmerica What @dhepburn said.         NaN
# 1  @VirginAmerica plus you've added commercials t...         NaN
# 2  @VirginAmerica I didn't today... Must mean I n...         NaN
# 3  @VirginAmerica it's really aggressive to blast...         NaN
# 4  @VirginAmerica and it's a really big bad thing...         NaN
#
#                tweet_created tweet_location               user_timezone
# 0  2015-02-24 11:35:52 -0800            NaN  Eastern Time (US & Canada)
# 1  2015-02-24 11:15:59 -0800            NaN  Pacific Time (US & Canada)
# 2  2015-02-24 11:15:48 -0800      Lets Play  Central Time (US & Canada)
# 3  2015-02-24 11:15:36 -0800            NaN  Pacific Time (US & Canada)
# 4  2015-02-24 11:14:45 -0800            NaN  Pacific Time (US & Canada)

# %%
df=df_[["airline_sentiment", "text"]].copy()

# %%
df.head()
# Out:
#   airline_sentiment                                               text
# 0           neutral                @VirginAmerica What @dhepburn said.
# 1          positive  @VirginAmerica plus you've added commercials t...
# 2           neutral  @VirginAmerica I didn't today... Must mean I n...
# 3          negative  @VirginAmerica it's really aggressive to blast...
# 4          negative  @VirginAmerica and it's a really big bad thing...

# %%
df["airline_sentiment"].hist()
#it is unbalance dataset
# Out:
# <Axes: >

# %%
target_map={'positive':1,'negative':0, 'neutral':2}
df['target']=df['airline_sentiment'].map(target_map)

# %%
# df2=df[['target','text']].copy()
# df2.head()
df2=df[['text', 'target']]
df2.columns=['sentence','label']
df2.to_csv('data.csv', index=None)
df2.head()
# Out:
#                                             sentence  label
# 0                @VirginAmerica What @dhepburn said.      2
# 1  @VirginAmerica plus you've added commercials t...      1
# 2  @VirginAmerica I didn't today... Must mean I n...      2
# 3  @VirginAmerica it's really aggressive to blast...      0
# 4  @VirginAmerica and it's a really big bad thing...      0

# %%
# !head data.csv
# Out:
# sentence,label
# @VirginAmerica What @dhepburn said.,2
# @VirginAmerica plus you've added commercials to the experience... tacky.,1
# @VirginAmerica I didn't today... Must mean I need to take another trip!,2
# "@VirginAmerica it's really aggressive to blast obnoxious ""entertainment"" in your guests' faces &amp; they have little recourse",0
# @VirginAmerica and it's a really big bad thing about it,0
# "@VirginAmerica seriously would pay $30 a flight for seats that didn't have this playing.
# it's really the only bad thing about flying VA",0
# "@VirginAmerica yes, nearly every time I fly VX this “ear worm” won’t go away :)",1
# "@VirginAmerica Really missed a prime opportunity for Men Without Hats parody, there. https://t.co/mWpG7grEZP",2

# %%
#the same as above code
# df2=df[['text','target']].copy()
# df2.head()

# %%
#when we load data_datset, we can use it to load in our csv as a hugging faced dataset
from datasets import load_dataset
raw_dataset=load_dataset('csv',data_files='data.csv')
# Out:
# Downloading data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Extracting data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Generating train split: 0 examples [00:00, ? examples/s]

# %%
raw_dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['sentence', 'label'],
#         num_rows: 14640
#     })
# })

# %%
split=raw_dataset['train'].train_test_split(test_size=0.3,seed=42)

# %%
split
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['sentence', 'label'],
#         num_rows: 10248
#     })
#     test: Dataset({
#         features: ['sentence', 'label'],
#         num_rows: 4392
#     })
# })

# %%
#when we have multiple csv files
# raw_dataset=load_dataset('csv',data_files=['data.csv','files2.csv'])

# %%
checkpoint="distilbert-base-cased"

# %%
from transformers import AutoTokenizer

# %%
tokenizer=AutoTokenizer.from_pretrained(checkpoint)

# %%
def tokenize_fn(batch):
  #padding handled automatically by trainer
  return tokenizer(batch['sentence'], truncation=True)

# %%
#apply tokeize function in our train test split by using the map method
tokenized_datasets=split.map(tokenize_fn,batched=True)
# Out:
# Map:   0%|          | 0/10248 [00:00<?, ? examples/s]
# Map:   0%|          | 0/4392 [00:00<?, ? examples/s]

# %%
tokenized_datasets
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['sentence', 'label', 'input_ids', 'attention_mask'],
#         num_rows: 10248
#     })
#     test: Dataset({
#         features: ['sentence', 'label', 'input_ids', 'attention_mask'],
#         num_rows: 4392
#     })
# })

# %%
from transformers import AutoModelForSequenceClassification,Trainer ,TrainingArguments

# %%
model= AutoModelForSequenceClassification.from_pretrained(
    checkpoint,num_labels=3
)
# Out:
# Some weights of the model checkpoint at distilbert-base-cased were not used when initializing DistilBertForSequenceClassification: ['vocab_projector.weight', 'vocab_layer_norm.bias', 'vocab_transform.weight', 'vocab_layer_norm.weight', 'vocab_transform.bias', 'vocab_projector.bias']
# - This IS expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-cased and are newly initialized: ['pre_classifier.weight', 'classifier.bias', 'classifier.weight', 'pre_classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
# !pip install torchinfo
# Out:
# Requirement already satisfied: torchinfo in /usr/local/lib/python3.10/dist-packages (1.8.0)

# %%
from torchinfo import summary

# %%
summary(model)
# Out:
# ================================================================================
# Layer (type:depth-idx)                                  Param #
# ================================================================================
# DistilBertForSequenceClassification                     --
# ├─DistilBertModel: 1-1                                  --
# │    └─Embeddings: 2-1                                  --
# │    │    └─Embedding: 3-1                              22,268,928
# │    │    └─Embedding: 3-2                              393,216
# │    │    └─LayerNorm: 3-3                              1,536
# │    │    └─Dropout: 3-4                                --
# │    └─Transformer: 2-2                                 --
# │    │    └─ModuleList: 3-5                             42,527,232
# ├─Linear: 1-2                                           590,592
# ├─Linear: 1-3                                           2,307
# ├─Dropout: 1-4                                          --
# ================================================================================
# Total params: 65,783,811
# Trainable params: 65,783,811
# Non-trainable params: 0
# ================================================================================

# %%
# !pip install datasets transformers==4.28.0
# Out:
# Requirement already satisfied: datasets in /usr/local/lib/python3.10/dist-packages (2.14.4)
# Requirement already satisfied: transformers==4.28.0 in /usr/local/lib/python3.10/dist-packages (4.28.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers==4.28.0) (3.12.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from transformers==4.28.0) (0.16.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers==4.28.0) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers==4.28.0) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers==4.28.0) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers==4.28.0) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers==4.28.0) (2.31.0)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.10/dist-packages (from transformers==4.28.0) (0.13.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers==4.28.0) (4.66.1)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (9.0.0)
# Requirement already satisfied: dill<0.3.8,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.3.7)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (1.5.3)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets) (3.3.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.10/dist-packages (from datasets) (0.70.15)
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.8.5)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (3.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.11.0->transformers==4.28.0) (4.7.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.28.0) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.28.0) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.28.0) (2023.7.22)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2023.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->datasets) (1.16.0)

# %%
training_args=TrainingArguments(
    output_dir='training_dir',
    evaluation_strategy='epoch',
    save_strategy='epoch',
    num_train_epochs=3,
    per_device_train_batch_size=16, #specify batch file for training and eval
    per_device_eval_batch_size=64,
)

# %%
def compute_metrics(logits_and_labels):
  logits,labels=logits_and_labels
  predictions=np.argmax(logits,axis=-1)
  acc=np.mean(predictions==labels)
  f1=f1_score(labels,predictions,average='macro')
  return{'accuracy': acc, 'f1': f1}

# %%
trainer=Trainer(
    model,
    training_args,
    train_dataset=tokenized_datasets["train"],
    eval_dataset=tokenized_datasets['test'],
    tokenizer=tokenizer,
    compute_metrics=compute_metrics,
)

# %%
trainer.train()
#The training loss indicates how well the model is fitting the training data, while the validation loss indicates how well the model fits new data.
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/optimization.py:391: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# You're using a DistilBertTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
#     <div>
#
#       <progress value='1923' max='1923' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1923/1923 03:15, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>F1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.550000</td>
#       <td>0.433749</td>
#       <td>0.825820</td>
#       <td>0.771700</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.346700</td>
#       <td>0.477088</td>
#       <td>0.834699</td>
#       <td>0.786937</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.235500</td>
#       <td>0.645719</td>
#       <td>0.839481</td>
#       <td>0.788098</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=1923, training_loss=0.32809543857584383, metrics={'train_runtime': 198.9079, 'train_samples_per_second': 154.564, 'train_steps_per_second': 9.668, 'total_flos': 388376501242176.0, 'train_loss': 0.32809543857584383, 'epoch': 3.0})

# %%
# !ls training_dir
# Out:
# checkpoint-1282  checkpoint-1923  checkpoint-641  runs

# %%
from transformers import pipeline

# %%
#we work with the best epoch which is the first epoch
savedmodel=pipeline('text-classification', model='training_dir/checkpoint-1282', device=0)

# %%
#how to access test
split['test']
# Out:
# Dataset({
#     features: ['sentence', 'label'],
#     num_rows: 4392
# })

# %%
test_pred=savedmodel(split['test']["sentence"])

# %%
torch.cuda.is_available()
# Out:
# True

# %%
test_pred
# Out:
# [{'label': 'LABEL_1', 'score': 0.9634993672370911},
#  {'label': 'LABEL_1', 'score': 0.9115362167358398},
#  {'label': 'LABEL_2', 'score': 0.40921592712402344},
#  {'label': 'LABEL_1', 'score': 0.8610964417457581},
#  {'label': 'LABEL_2', 'score': 0.9155072569847107},
#  {'label': 'LABEL_0', 'score': 0.9925273656845093},
#  {'label': 'LABEL_2', 'score': 0.972826361656189},
#  {'label': 'LABEL_2', 'score': 0.9844282865524292},
#  {'label': 'LABEL_1', 'score': 0.6210298538208008},
#  {'label': 'LABEL_0', 'score': 0.9946954846382141},
#  {'label': 'LABEL_0', 'score': 0.8118512630462646},
#  {'label': 'LABEL_0', 'score': 0.9866994619369507},
#  {'label': 'LABEL_1', 'score': 0.9629762172698975},
#  {'label': 'LABEL_0', 'score': 0.991787850856781},
#  {'label': 'LABEL_2', 'score': 0.9869914650917053},
#  {'label': 'LABEL_2', 'score': 0.8492730855941772},
#  {'label': 'LABEL_0', 'score': 0.6664790511131287},
#  {'label': 'LABEL_0', 'score': 0.9953208565711975},
#  {'label': 'LABEL_0', 'score': 0.8011534214019775},
#  {'label': 'LABEL_0', 'score': 0.9914348721504211},
#  {'label': 'LABEL_2', 'score': 0.809169590473175},
#  {'label': 'LABEL_2', 'score': 0.8633488416671753},
#  {'label': 'LABEL_0', 'score': 0.6466114521026611},
#  {'label': 'LABEL_1', 'score': 0.8526726365089417},
#  {'label': 'LABEL_0', 'score': 0.994418740272522},
#  {'label': 'LABEL_0', 'score': 0.6099421381950378},
#  {'label': 'LABEL_0', 'score': 0.9959902167320251},
#  {'label': 'LABEL_0', 'score': 0.992890477180481},
#  {'label': 'LABEL_0', 'score': 0.9958807229995728},
#  {'label': 'LABEL_0', 'score': 0.9771797060966492},
#  {'label': 'LABEL_0', 'score': 0.995768666267395},
#  {'label': 'LABEL_1', 'score': 0.607995331287384},
#  {'label': 'LABEL_0', 'score': 0.9949384927749634},
#  {'label': 'LABEL_0', 'score': 0.9951168298721313},
#  {'label': 'LABEL_1', 'score': 0.9619790315628052},
#  {'label': 'LABEL_0', 'score': 0.9926177859306335},
#  {'label': 'LABEL_1', 'score': 0.6613578796386719},
#  {'label': 'LABEL_0', 'score': 0.9420604109764099},
#  {'label': 'LABEL_0', 'score': 0.967488706111908},
#  {'label': 'LABEL_2', 'score': 0.8252432942390442},
#  {'label': 'LABEL_0', 'score': 0.9938785433769226},
#  {'label': 'LABEL_0', 'score': 0.9540848731994629},
#  {'label': 'LABEL_0', 'score': 0.9922254085540771},
#  {'label': 'LABEL_0', 'score': 0.8763914108276367},
#  {'label': 'LABEL_1', 'score': 0.7030497193336487},
#  {'label': 'LABEL_2', 'score': 0.5446683764457703},
#  {'label': 'LABEL_0', 'score': 0.9630594253540039},
#  {'label': 'LABEL_1', 'score': 0.9292731285095215},
#  {'label': 'LABEL_0', 'score': 0.994831383228302},
#  {'label': 'LABEL_0', 'score': 0.9963919520378113},
#  {'label': 'LABEL_0', 'score': 0.9856248497962952},
#  {'label': 'LABEL_0', 'score': 0.8896291851997375},
#  {'label': 'LABEL_0', 'score': 0.9403265714645386},
#  {'label': 'LABEL_0', 'score': 0.9960384368896484},
#  {'label': 'LABEL_0', 'score': 0.9917634725570679},
#  {'label': 'LABEL_0', 'score': 0.9950761198997498},
#  {'label': 'LABEL_0', 'score': 0.5766170024871826},
#  {'label': 'LABEL_2', 'score': 0.9676340222358704},
#  {'label': 'LABEL_0', 'score': 0.9936741590499878},
#  {'label': 'LABEL_1', 'score': 0.7821975946426392},
#  {'label': 'LABEL_0', 'score': 0.9887978434562683},
#  {'label': 'LABEL_0', 'score': 0.9911989569664001},
#  {'label': 'LABEL_0', 'score': 0.9946668148040771},
#  {'label': 'LABEL_0', 'score': 0.9892288446426392},
#  {'label': 'LABEL_0', 'score': 0.8292487859725952},
#  {'label': 'LABEL_2', 'score': 0.982541024684906},
#  {'label': 'LABEL_0', 'score': 0.9921947717666626},
#  {'label': 'LABEL_0', 'score': 0.9919601082801819},
#  {'label': 'LABEL_0', 'score': 0.9957678318023682},
#  {'label': 'LABEL_0', 'score': 0.7296074628829956},
#  {'label': 'LABEL_0', 'score': 0.9732245802879333},
#  {'label': 'LABEL_0', 'score': 0.9405409097671509},
#  {'label': 'LABEL_0', 'score': 0.5452940464019775},
#  {'label': 'LABEL_0', 'score': 0.9411430954933167},
#  {'label': 'LABEL_2', 'score': 0.8659886121749878},
#  {'label': 'LABEL_0', 'score': 0.9735859036445618},
#  {'label': 'LABEL_0', 'score': 0.9954665899276733},
#  {'label': 'LABEL_0', 'score': 0.9785544276237488},
#  {'label': 'LABEL_0', 'score': 0.9936886429786682},
#  {'label': 'LABEL_0', 'score': 0.9113826155662537},
#  {'label': 'LABEL_0', 'score': 0.9963010549545288},
#  {'label': 'LABEL_0', 'score': 0.6101396679878235},
#  {'label': 'LABEL_1', 'score': 0.9486039280891418},
#  {'label': 'LABEL_0', 'score': 0.6588779091835022},
#  {'label': 'LABEL_1', 'score': 0.9008702039718628},
#  {'label': 'LABEL_2', 'score': 0.985023021697998},
#  {'label': 'LABEL_0', 'score': 0.9947044253349304},
#  {'label': 'LABEL_0', 'score': 0.9838976263999939},
#  {'label': 'LABEL_0', 'score': 0.9835293292999268},
#  {'label': 'LABEL_2', 'score': 0.7881118655204773},
#  {'label': 'LABEL_0', 'score': 0.8502727150917053},
#  {'label': 'LABEL_0', 'score': 0.9663283824920654},
#  {'label': 'LABEL_0', 'score': 0.9882212281227112},
#  {'label': 'LABEL_1', 'score': 0.7702365517616272},
#  {'label': 'LABEL_0', 'score': 0.9712127447128296},
#  {'label': 'LABEL_0', 'score': 0.9833884239196777},
#  {'label': 'LABEL_0', 'score': 0.9954074025154114},
#  {'label': 'LABEL_0', 'score': 0.9930349588394165},
#  {'label': 'LABEL_0', 'score': 0.955270528793335},
#  {'label': 'LABEL_0', 'score': 0.9906871914863586},
#  {'label': 'LABEL_0', 'score': 0.9957193732261658},
#  {'label': 'LABEL_2', 'score': 0.9875083565711975},
#  {'label': 'LABEL_2', 'score': 0.938749372959137},
#  {'label': 'LABEL_2', 'score': 0.8899176716804504},
#  {'label': 'LABEL_2', 'score': 0.8759258389472961},
#  {'label': 'LABEL_0', 'score': 0.9943244457244873},
#  {'label': 'LABEL_0', 'score': 0.7344552278518677},
#  {'label': 'LABEL_0', 'score': 0.9927343130111694},
#  {'label': 'LABEL_0', 'score': 0.9613828063011169},
#  {'label': 'LABEL_0', 'score': 0.9953194260597229},
#  {'label': 'LABEL_0', 'score': 0.9615980982780457},
#  {'label': 'LABEL_0', 'score': 0.9957354068756104},
#  {'label': 'LABEL_0', 'score': 0.9717298746109009},
#  {'label': 'LABEL_2', 'score': 0.7567479014396667},
#  {'label': 'LABEL_0', 'score': 0.9738380908966064},
#  {'label': 'LABEL_2', 'score': 0.9697973132133484},
#  {'label': 'LABEL_0', 'score': 0.969739556312561},
#  {'label': 'LABEL_2', 'score': 0.8162049651145935},
#  {'label': 'LABEL_0', 'score': 0.9914016127586365},
#  {'label': 'LABEL_2', 'score': 0.9579179286956787},
#  {'label': 'LABEL_2', 'score': 0.9787551760673523},
#  {'label': 'LABEL_2', 'score': 0.9460022449493408},
#  {'label': 'LABEL_2', 'score': 0.9448423385620117},
#  {'label': 'LABEL_2', 'score': 0.97700434923172},
#  {'label': 'LABEL_0', 'score': 0.9790856242179871},
#  {'label': 'LABEL_0', 'score': 0.9962934851646423},
#  {'label': 'LABEL_0', 'score': 0.9840936064720154},
#  {'label': 'LABEL_0', 'score': 0.9949618577957153},
#  {'label': 'LABEL_2', 'score': 0.5609226822853088},
#  {'label': 'LABEL_0', 'score': 0.9951640367507935},
#  {'label': 'LABEL_1', 'score': 0.8615517616271973},
#  {'label': 'LABEL_0', 'score': 0.9948004484176636},
#  {'label': 'LABEL_0', 'score': 0.881951630115509},
#  {'label': 'LABEL_1', 'score': 0.9772608876228333},
#  {'label': 'LABEL_2', 'score': 0.9801310300827026},
#  {'label': 'LABEL_0', 'score': 0.927089512348175},
#  {'label': 'LABEL_0', 'score': 0.9931381344795227},
#  {'label': 'LABEL_0', 'score': 0.9470421671867371},
#  {'label': 'LABEL_0', 'score': 0.9923059344291687},
#  {'label': 'LABEL_0', 'score': 0.995960533618927},
#  {'label': 'LABEL_0', 'score': 0.980682373046875},
#  {'label': 'LABEL_0', 'score': 0.9711959362030029},
#  {'label': 'LABEL_0', 'score': 0.9897878170013428},
#  {'label': 'LABEL_0', 'score': 0.9900051951408386},
#  {'label': 'LABEL_2', 'score': 0.9211023449897766},
#  {'label': 'LABEL_2', 'score': 0.8334671854972839},
#  {'label': 'LABEL_2', 'score': 0.8610664010047913},
#  {'label': 'LABEL_0', 'score': 0.9956302642822266},
#  {'label': 'LABEL_0', 'score': 0.9939752221107483},
#  {'label': 'LABEL_0', 'score': 0.9960565567016602},
#  {'label': 'LABEL_0', 'score': 0.9948923587799072},
#  {'label': 'LABEL_2', 'score': 0.8673408031463623},
#  {'label': 'LABEL_2', 'score': 0.987951934337616},
#  {'label': 'LABEL_2', 'score': 0.9578620195388794},
#  {'label': 'LABEL_1', 'score': 0.948010265827179},
#  {'label': 'LABEL_2', 'score': 0.845033586025238},
#  {'label': 'LABEL_0', 'score': 0.9772772789001465},
#  {'label': 'LABEL_0', 'score': 0.9523058533668518},
#  {'label': 'LABEL_0', 'score': 0.9950245022773743},
#  {'label': 'LABEL_0', 'score': 0.994114100933075},
#  {'label': 'LABEL_2', 'score': 0.5120917558670044},
#  {'label': 'LABEL_0', 'score': 0.9957426190376282},
#  {'label': 'LABEL_1', 'score': 0.711078405380249},
#  {'label': 'LABEL_0', 'score': 0.9943040013313293},
#  {'label': 'LABEL_0', 'score': 0.5751677751541138},
#  {'label': 'LABEL_0', 'score': 0.6847797632217407},
#  {'label': 'LABEL_0', 'score': 0.995680570602417},
#  {'label': 'LABEL_0', 'score': 0.9899709820747375},
#  {'label': 'LABEL_2', 'score': 0.9152097702026367},
#  {'label': 'LABEL_2', 'score': 0.9856005311012268},
#  {'label': 'LABEL_0', 'score': 0.9941686391830444},
#  {'label': 'LABEL_0', 'score': 0.8120936155319214},
#  {'label': 'LABEL_0', 'score': 0.6926907300949097},
#  {'label': 'LABEL_2', 'score': 0.9055296778678894},
#  {'label': 'LABEL_2', 'score': 0.5443899631500244},
#  {'label': 'LABEL_0', 'score': 0.47842535376548767},
#  {'label': 'LABEL_0', 'score': 0.7832580804824829},
#  {'label': 'LABEL_0', 'score': 0.9954965114593506},
#  {'label': 'LABEL_0', 'score': 0.9864083528518677},
#  {'label': 'LABEL_0', 'score': 0.9343811869621277},
#  {'label': 'LABEL_0', 'score': 0.9863680005073547},
#  {'label': 'LABEL_0', 'score': 0.7933911085128784},
#  {'label': 'LABEL_0', 'score': 0.9962432384490967},
#  {'label': 'LABEL_0', 'score': 0.9947446584701538},
#  {'label': 'LABEL_0', 'score': 0.9959970712661743},
#  {'label': 'LABEL_2', 'score': 0.8957156538963318},
#  {'label': 'LABEL_2', 'score': 0.9364181756973267},
#  {'label': 'LABEL_0', 'score': 0.9938737154006958},
#  {'label': 'LABEL_1', 'score': 0.9653801321983337},
#  {'label': 'LABEL_0', 'score': 0.7234577536582947},
#  {'label': 'LABEL_0', 'score': 0.892168402671814},
#  {'label': 'LABEL_0', 'score': 0.9911407828330994},
#  {'label': 'LABEL_0', 'score': 0.9799339771270752},
#  {'label': 'LABEL_0', 'score': 0.7431817650794983},
#  {'label': 'LABEL_0', 'score': 0.8659750819206238},
#  {'label': 'LABEL_2', 'score': 0.9439847469329834},
#  {'label': 'LABEL_1', 'score': 0.969025194644928},
#  {'label': 'LABEL_2', 'score': 0.5906763076782227},
#  {'label': 'LABEL_0', 'score': 0.9948230981826782},
#  {'label': 'LABEL_0', 'score': 0.9828208684921265},
#  {'label': 'LABEL_2', 'score': 0.8849263787269592},
#  {'label': 'LABEL_0', 'score': 0.5377628803253174},
#  {'label': 'LABEL_2', 'score': 0.9381084442138672},
#  {'label': 'LABEL_0', 'score': 0.9958206415176392},
#  {'label': 'LABEL_0', 'score': 0.9888672232627869},
#  {'label': 'LABEL_1', 'score': 0.8663529753684998},
#  {'label': 'LABEL_2', 'score': 0.9864087104797363},
#  {'label': 'LABEL_0', 'score': 0.995172917842865},
#  {'label': 'LABEL_0', 'score': 0.9926300048828125},
#  {'label': 'LABEL_0', 'score': 0.9602968692779541},
#  {'label': 'LABEL_2', 'score': 0.47573453187942505},
#  {'label': 'LABEL_2', 'score': 0.9678221344947815},
#  {'label': 'LABEL_1', 'score': 0.8975163698196411},
#  {'label': 'LABEL_2', 'score': 0.7135524749755859},
#  {'label': 'LABEL_0', 'score': 0.9641534090042114},
#  {'label': 'LABEL_2', 'score': 0.9902764558792114},
#  {'label': 'LABEL_2', 'score': 0.9892088770866394},
#  {'label': 'LABEL_0', 'score': 0.9931454658508301},
#  {'label': 'LABEL_2', 'score': 0.950980544090271},
#  {'label': 'LABEL_2', 'score': 0.9418386220932007},
#  {'label': 'LABEL_0', 'score': 0.9507986903190613},
#  {'label': 'LABEL_0', 'score': 0.9957526922225952},
#  {'label': 'LABEL_0', 'score': 0.9827548861503601},
#  {'label': 'LABEL_2', 'score': 0.9587910771369934},
#  {'label': 'LABEL_1', 'score': 0.8991811275482178},
#  {'label': 'LABEL_0', 'score': 0.8240936994552612},
#  {'label': 'LABEL_0', 'score': 0.5613282322883606},
#  {'label': 'LABEL_0', 'score': 0.9939600229263306},
#  {'label': 'LABEL_0', 'score': 0.9563421607017517},
#  {'label': 'LABEL_0', 'score': 0.9176979064941406},
#  {'label': 'LABEL_2', 'score': 0.891232967376709},
#  {'label': 'LABEL_0', 'score': 0.8073616623878479},
#  {'label': 'LABEL_0', 'score': 0.9841175079345703},
#  {'label': 'LABEL_0', 'score': 0.9934624433517456},
#  {'label': 'LABEL_0', 'score': 0.983311653137207},
#  {'label': 'LABEL_1', 'score': 0.9422362446784973},
#  {'label': 'LABEL_0', 'score': 0.9380286335945129},
#  {'label': 'LABEL_0', 'score': 0.9544876217842102},
#  {'label': 'LABEL_0', 'score': 0.9952865242958069},
#  {'label': 'LABEL_0', 'score': 0.9841296672821045},
#  {'label': 'LABEL_0', 'score': 0.988395094871521},
#  {'label': 'LABEL_2', 'score': 0.863865315914154},
#  {'label': 'LABEL_0', 'score': 0.7867271900177002},
#  {'label': 'LABEL_1', 'score': 0.47349533438682556},
#  {'label': 'LABEL_0', 'score': 0.9957138299942017},
#  {'label': 'LABEL_0', 'score': 0.9767637252807617},
#  {'label': 'LABEL_0', 'score': 0.9558426737785339},
#  {'label': 'LABEL_2', 'score': 0.6404081583023071},
#  {'label': 'LABEL_0', 'score': 0.7224671840667725},
#  {'label': 'LABEL_2', 'score': 0.9803604483604431},
#  {'label': 'LABEL_0', 'score': 0.9939372539520264},
#  {'label': 'LABEL_0', 'score': 0.9924213290214539},
#  {'label': 'LABEL_0', 'score': 0.9952200055122375},
#  {'label': 'LABEL_0', 'score': 0.994358241558075},
#  {'label': 'LABEL_0', 'score': 0.9946505427360535},
#  {'label': 'LABEL_0', 'score': 0.7515500783920288},
#  {'label': 'LABEL_0', 'score': 0.825900137424469},
#  {'label': 'LABEL_0', 'score': 0.9962235689163208},
#  {'label': 'LABEL_0', 'score': 0.974946141242981},
#  {'label': 'LABEL_2', 'score': 0.632835328578949},
#  {'label': 'LABEL_1', 'score': 0.9722723960876465},
#  {'label': 'LABEL_0', 'score': 0.9882668852806091},
#  {'label': 'LABEL_0', 'score': 0.9927529096603394},
#  {'label': 'LABEL_1', 'score': 0.982451856136322},
#  {'label': 'LABEL_1', 'score': 0.5162892937660217},
#  {'label': 'LABEL_0', 'score': 0.68587726354599},
#  {'label': 'LABEL_0', 'score': 0.9945711493492126},
#  {'label': 'LABEL_0', 'score': 0.978510856628418},
#  {'label': 'LABEL_0', 'score': 0.7168580293655396},
#  {'label': 'LABEL_1', 'score': 0.9584853053092957},
#  {'label': 'LABEL_0', 'score': 0.9957343935966492},
#  {'label': 'LABEL_0', 'score': 0.9147089123725891},
#  {'label': 'LABEL_2', 'score': 0.6335824131965637},
#  {'label': 'LABEL_0', 'score': 0.913535475730896},
#  {'label': 'LABEL_0', 'score': 0.7570015788078308},
#  {'label': 'LABEL_1', 'score': 0.8166549205780029},
#  {'label': 'LABEL_0', 'score': 0.9961200952529907},
#  {'label': 'LABEL_2', 'score': 0.9436665773391724},
#  {'label': 'LABEL_2', 'score': 0.9863322973251343},
#  {'label': 'LABEL_0', 'score': 0.9544833898544312},
#  {'label': 'LABEL_0', 'score': 0.9913687109947205},
#  {'label': 'LABEL_0', 'score': 0.9868069291114807},
#  {'label': 'LABEL_2', 'score': 0.9358484745025635},
#  {'label': 'LABEL_0', 'score': 0.9808580279350281},
#  {'label': 'LABEL_1', 'score': 0.9599819183349609},
#  {'label': 'LABEL_2', 'score': 0.58439040184021},
#  {'label': 'LABEL_0', 'score': 0.9748240113258362},
#  {'label': 'LABEL_0', 'score': 0.993026614189148},
#  {'label': 'LABEL_0', 'score': 0.9936535358428955},
#  {'label': 'LABEL_0', 'score': 0.9957934617996216},
#  {'label': 'LABEL_0', 'score': 0.8205642700195312},
#  {'label': 'LABEL_0', 'score': 0.994866132736206},
#  {'label': 'LABEL_2', 'score': 0.8936593532562256},
#  {'label': 'LABEL_2', 'score': 0.8859411478042603},
#  {'label': 'LABEL_0', 'score': 0.915249764919281},
#  {'label': 'LABEL_0', 'score': 0.9883477091789246},
#  {'label': 'LABEL_2', 'score': 0.9577150344848633},
#  {'label': 'LABEL_2', 'score': 0.9893620610237122},
#  {'label': 'LABEL_0', 'score': 0.9951760768890381},
#  {'label': 'LABEL_0', 'score': 0.8664572834968567},
#  {'label': 'LABEL_0', 'score': 0.9934780597686768},
#  {'label': 'LABEL_2', 'score': 0.9537802338600159},
#  {'label': 'LABEL_2', 'score': 0.9370353817939758},
#  {'label': 'LABEL_0', 'score': 0.9944000840187073},
#  {'label': 'LABEL_2', 'score': 0.9338501691818237},
#  {'label': 'LABEL_0', 'score': 0.8851305842399597},
#  {'label': 'LABEL_1', 'score': 0.7464064359664917},
#  {'label': 'LABEL_2', 'score': 0.9541044235229492},
#  {'label': 'LABEL_2', 'score': 0.8499389886856079},
#  {'label': 'LABEL_0', 'score': 0.9873098731040955},
#  {'label': 'LABEL_0', 'score': 0.9717063903808594},
#  {'label': 'LABEL_0', 'score': 0.9880579710006714},
#  {'label': 'LABEL_0', 'score': 0.9958565831184387},
#  {'label': 'LABEL_2', 'score': 0.8603643178939819},
#  {'label': 'LABEL_0', 'score': 0.9580285549163818},
#  {'label': 'LABEL_1', 'score': 0.8249267935752869},
#  {'label': 'LABEL_2', 'score': 0.5559347867965698},
#  {'label': 'LABEL_0', 'score': 0.9823094010353088},
#  {'label': 'LABEL_0', 'score': 0.9755394458770752},
#  {'label': 'LABEL_0', 'score': 0.9902042150497437},
#  {'label': 'LABEL_0', 'score': 0.9936408400535583},
#  {'label': 'LABEL_0', 'score': 0.9796078205108643},
#  {'label': 'LABEL_2', 'score': 0.6408911943435669},
#  {'label': 'LABEL_0', 'score': 0.7999840378761292},
#  {'label': 'LABEL_0', 'score': 0.9876838326454163},
#  {'label': 'LABEL_0', 'score': 0.8415480256080627},
#  {'label': 'LABEL_1', 'score': 0.5852428078651428},
#  {'label': 'LABEL_0', 'score': 0.9875937104225159},
#  {'label': 'LABEL_0', 'score': 0.6337700486183167},
#  {'label': 'LABEL_0', 'score': 0.9424164295196533},
#  {'label': 'LABEL_2', 'score': 0.9873544573783875},
#  {'label': 'LABEL_0', 'score': 0.9934775829315186},
#  {'label': 'LABEL_0', 'score': 0.9480348825454712},
#  {'label': 'LABEL_1', 'score': 0.6846334338188171},
#  {'label': 'LABEL_0', 'score': 0.9900038838386536},
#  {'label': 'LABEL_0', 'score': 0.9930040240287781},
#  {'label': 'LABEL_2', 'score': 0.6532273292541504},
#  {'label': 'LABEL_0', 'score': 0.9913553595542908},
#  {'label': 'LABEL_2', 'score': 0.9452125430107117},
#  {'label': 'LABEL_1', 'score': 0.7733976244926453},
#  {'label': 'LABEL_0', 'score': 0.797897219657898},
#  {'label': 'LABEL_0', 'score': 0.9931100606918335},
#  {'label': 'LABEL_0', 'score': 0.9915177226066589},
#  {'label': 'LABEL_0', 'score': 0.9676671624183655},
#  {'label': 'LABEL_0', 'score': 0.8278573155403137},
#  {'label': 'LABEL_2', 'score': 0.7937898635864258},
#  {'label': 'LABEL_0', 'score': 0.8177988529205322},
#  {'label': 'LABEL_0', 'score': 0.9030613303184509},
#  {'label': 'LABEL_0', 'score': 0.9888430833816528},
#  {'label': 'LABEL_1', 'score': 0.9642203450202942},
#  {'label': 'LABEL_2', 'score': 0.942241907119751},
#  {'label': 'LABEL_1', 'score': 0.8900989890098572},
#  {'label': 'LABEL_1', 'score': 0.9564841389656067},
#  {'label': 'LABEL_0', 'score': 0.9956570863723755},
#  {'label': 'LABEL_2', 'score': 0.9869211912155151},
#  {'label': 'LABEL_2', 'score': 0.87303626537323},
#  {'label': 'LABEL_0', 'score': 0.7944427132606506},
#  {'label': 'LABEL_1', 'score': 0.9100207686424255},
#  {'label': 'LABEL_2', 'score': 0.7541131973266602},
#  {'label': 'LABEL_0', 'score': 0.9930619597434998},
#  {'label': 'LABEL_0', 'score': 0.7987478375434875},
#  {'label': 'LABEL_0', 'score': 0.9752715229988098},
#  {'label': 'LABEL_0', 'score': 0.9901734590530396},
#  {'label': 'LABEL_0', 'score': 0.6111284494400024},
#  {'label': 'LABEL_2', 'score': 0.9708564877510071},
#  {'label': 'LABEL_0', 'score': 0.995120108127594},
#  {'label': 'LABEL_0', 'score': 0.9954853653907776},
#  {'label': 'LABEL_1', 'score': 0.9479995369911194},
#  {'label': 'LABEL_0', 'score': 0.9540975689888},
#  {'label': 'LABEL_0', 'score': 0.9448591470718384},
#  {'label': 'LABEL_2', 'score': 0.9736407399177551},
#  {'label': 'LABEL_0', 'score': 0.9943923354148865},
#  {'label': 'LABEL_1', 'score': 0.9282078742980957},
#  {'label': 'LABEL_0', 'score': 0.9922972321510315},
#  {'label': 'LABEL_2', 'score': 0.49564772844314575},
#  {'label': 'LABEL_0', 'score': 0.9947746396064758},
#  {'label': 'LABEL_2', 'score': 0.9727947115898132},
#  {'label': 'LABEL_0', 'score': 0.8696995377540588},
#  {'label': 'LABEL_1', 'score': 0.9714775085449219},
#  {'label': 'LABEL_2', 'score': 0.9870471954345703},
#  {'label': 'LABEL_0', 'score': 0.9944994449615479},
#  {'label': 'LABEL_0', 'score': 0.9884266257286072},
#  {'label': 'LABEL_0', 'score': 0.8471420407295227},
#  {'label': 'LABEL_0', 'score': 0.9838969707489014},
#  {'label': 'LABEL_1', 'score': 0.9806970357894897},
#  {'label': 'LABEL_0', 'score': 0.8572782278060913},
#  {'label': 'LABEL_0', 'score': 0.9933040738105774},
#  {'label': 'LABEL_1', 'score': 0.8835024833679199},
#  {'label': 'LABEL_1', 'score': 0.9489579796791077},
#  {'label': 'LABEL_0', 'score': 0.762073278427124},
#  {'label': 'LABEL_0', 'score': 0.9952881336212158},
#  {'label': 'LABEL_0', 'score': 0.995298445224762},
#  {'label': 'LABEL_0', 'score': 0.9707540273666382},
#  {'label': 'LABEL_0', 'score': 0.9512982368469238},
#  {'label': 'LABEL_1', 'score': 0.9399316310882568},
#  {'label': 'LABEL_0', 'score': 0.9609412550926208},
#  {'label': 'LABEL_0', 'score': 0.9928981065750122},
#  {'label': 'LABEL_1', 'score': 0.6936699748039246},
#  {'label': 'LABEL_0', 'score': 0.9956592321395874},
#  {'label': 'LABEL_2', 'score': 0.6868525743484497},
#  {'label': 'LABEL_1', 'score': 0.5220078229904175},
#  {'label': 'LABEL_2', 'score': 0.6008551120758057},
#  {'label': 'LABEL_0', 'score': 0.9880051016807556},
#  {'label': 'LABEL_0', 'score': 0.9677176475524902},
#  {'label': 'LABEL_0', 'score': 0.991601288318634},
#  {'label': 'LABEL_0', 'score': 0.9919153451919556},
#  {'label': 'LABEL_1', 'score': 0.8628552556037903},
#  {'label': 'LABEL_0', 'score': 0.9844285249710083},
#  {'label': 'LABEL_2', 'score': 0.985550045967102},
#  {'label': 'LABEL_0', 'score': 0.9949641227722168},
#  {'label': 'LABEL_0', 'score': 0.9858456254005432},
#  {'label': 'LABEL_2', 'score': 0.8045393824577332},
#  {'label': 'LABEL_0', 'score': 0.9654616713523865},
#  {'label': 'LABEL_0', 'score': 0.5586242079734802},
#  {'label': 'LABEL_0', 'score': 0.8190256357192993},
#  {'label': 'LABEL_1', 'score': 0.5339424014091492},
#  {'label': 'LABEL_2', 'score': 0.9643683433532715},
#  {'label': 'LABEL_2', 'score': 0.9579150676727295},
#  {'label': 'LABEL_2', 'score': 0.9775106310844421},
#  {'label': 'LABEL_0', 'score': 0.9853690266609192},
#  {'label': 'LABEL_2', 'score': 0.9841921329498291},
#  {'label': 'LABEL_2', 'score': 0.9358908534049988},
#  {'label': 'LABEL_0', 'score': 0.9434395432472229},
#  {'label': 'LABEL_1', 'score': 0.9639186263084412},
#  {'label': 'LABEL_0', 'score': 0.9826748967170715},
#  {'label': 'LABEL_0', 'score': 0.8651144504547119},
#  {'label': 'LABEL_0', 'score': 0.5916979908943176},
#  {'label': 'LABEL_0', 'score': 0.852152943611145},
#  {'label': 'LABEL_0', 'score': 0.9943252205848694},
#  {'label': 'LABEL_0', 'score': 0.9535359144210815},
#  {'label': 'LABEL_2', 'score': 0.7803627848625183},
#  {'label': 'LABEL_0', 'score': 0.990011990070343},
#  {'label': 'LABEL_1', 'score': 0.7642524838447571},
#  {'label': 'LABEL_0', 'score': 0.7860939502716064},
#  {'label': 'LABEL_2', 'score': 0.8602463603019714},
#  {'label': 'LABEL_0', 'score': 0.7927164435386658},
#  {'label': 'LABEL_0', 'score': 0.8100936412811279},
#  {'label': 'LABEL_0', 'score': 0.9957442879676819},
#  {'label': 'LABEL_0', 'score': 0.6554551720619202},
#  {'label': 'LABEL_0', 'score': 0.9952548742294312},
#  {'label': 'LABEL_0', 'score': 0.9956455826759338},
#  {'label': 'LABEL_1', 'score': 0.48975980281829834},
#  {'label': 'LABEL_0', 'score': 0.9898714423179626},
#  {'label': 'LABEL_0', 'score': 0.9878088235855103},
#  {'label': 'LABEL_0', 'score': 0.9954406023025513},
#  {'label': 'LABEL_2', 'score': 0.7927080392837524},
#  {'label': 'LABEL_0', 'score': 0.9908598065376282},
#  {'label': 'LABEL_0', 'score': 0.995868444442749},
#  {'label': 'LABEL_2', 'score': 0.8794472813606262},
#  {'label': 'LABEL_0', 'score': 0.9952796697616577},
#  {'label': 'LABEL_0', 'score': 0.9939588308334351},
#  {'label': 'LABEL_2', 'score': 0.7655085921287537},
#  {'label': 'LABEL_2', 'score': 0.9772417545318604},
#  {'label': 'LABEL_0', 'score': 0.9815452694892883},
#  {'label': 'LABEL_0', 'score': 0.990202009677887},
#  {'label': 'LABEL_2', 'score': 0.6990531086921692},
#  {'label': 'LABEL_0', 'score': 0.9933379888534546},
#  {'label': 'LABEL_1', 'score': 0.9767628312110901},
#  {'label': 'LABEL_0', 'score': 0.8533762097358704},
#  {'label': 'LABEL_2', 'score': 0.7052196860313416},
#  {'label': 'LABEL_0', 'score': 0.9935259819030762},
#  {'label': 'LABEL_0', 'score': 0.9892048835754395},
#  {'label': 'LABEL_0', 'score': 0.9117558598518372},
#  {'label': 'LABEL_0', 'score': 0.9950516819953918},
#  {'label': 'LABEL_0', 'score': 0.8243054747581482},
#  {'label': 'LABEL_2', 'score': 0.9755197167396545},
#  {'label': 'LABEL_1', 'score': 0.9573026895523071},
#  {'label': 'LABEL_0', 'score': 0.994783341884613},
#  {'label': 'LABEL_1', 'score': 0.973739504814148},
#  {'label': 'LABEL_0', 'score': 0.5218214988708496},
#  {'label': 'LABEL_2', 'score': 0.9791248440742493},
#  {'label': 'LABEL_0', 'score': 0.5253534913063049},
#  {'label': 'LABEL_0', 'score': 0.9963967204093933},
#  {'label': 'LABEL_0', 'score': 0.8566131591796875},
#  {'label': 'LABEL_2', 'score': 0.9820491671562195},
#  {'label': 'LABEL_0', 'score': 0.9913046360015869},
#  {'label': 'LABEL_0', 'score': 0.7269306182861328},
#  {'label': 'LABEL_0', 'score': 0.9788740277290344},
#  {'label': 'LABEL_1', 'score': 0.9358031749725342},
#  {'label': 'LABEL_2', 'score': 0.941794753074646},
#  {'label': 'LABEL_2', 'score': 0.6619685888290405},
#  {'label': 'LABEL_0', 'score': 0.9891436696052551},
#  {'label': 'LABEL_0', 'score': 0.9946922659873962},
#  {'label': 'LABEL_2', 'score': 0.5741150379180908},
#  {'label': 'LABEL_0', 'score': 0.9960023760795593},
#  {'label': 'LABEL_2', 'score': 0.9834774136543274},
#  {'label': 'LABEL_2', 'score': 0.8844395279884338},
#  {'label': 'LABEL_2', 'score': 0.983950138092041},
#  {'label': 'LABEL_0', 'score': 0.9881945848464966},
#  {'label': 'LABEL_0', 'score': 0.9956488013267517},
#  {'label': 'LABEL_0', 'score': 0.98298579454422},
#  {'label': 'LABEL_0', 'score': 0.5093618035316467},
#  {'label': 'LABEL_2', 'score': 0.9826282262802124},
#  {'label': 'LABEL_0', 'score': 0.9946746826171875},
#  {'label': 'LABEL_0', 'score': 0.9783469438552856},
#  {'label': 'LABEL_2', 'score': 0.9024574160575867},
#  {'label': 'LABEL_2', 'score': 0.984056830406189},
#  {'label': 'LABEL_0', 'score': 0.9883363842964172},
#  {'label': 'LABEL_0', 'score': 0.9361278414726257},
#  {'label': 'LABEL_1', 'score': 0.7745059132575989},
#  {'label': 'LABEL_1', 'score': 0.9144346117973328},
#  {'label': 'LABEL_0', 'score': 0.9610186815261841},
#  {'label': 'LABEL_0', 'score': 0.9956100583076477},
#  {'label': 'LABEL_0', 'score': 0.8552120923995972},
#  {'label': 'LABEL_0', 'score': 0.9936702251434326},
#  {'label': 'LABEL_1', 'score': 0.9748172163963318},
#  {'label': 'LABEL_0', 'score': 0.9859915375709534},
#  {'label': 'LABEL_0', 'score': 0.9569759368896484},
#  {'label': 'LABEL_0', 'score': 0.9912514090538025},
#  {'label': 'LABEL_0', 'score': 0.9729859232902527},
#  {'label': 'LABEL_0', 'score': 0.9927581548690796},
#  {'label': 'LABEL_0', 'score': 0.9826959371566772},
#  {'label': 'LABEL_0', 'score': 0.9700140953063965},
#  {'label': 'LABEL_2', 'score': 0.9884359836578369},
#  {'label': 'LABEL_0', 'score': 0.9893921613693237},
#  {'label': 'LABEL_0', 'score': 0.9749788641929626},
#  {'label': 'LABEL_0', 'score': 0.978743851184845},
#  {'label': 'LABEL_0', 'score': 0.9950829744338989},
#  {'label': 'LABEL_2', 'score': 0.9066779613494873},
#  {'label': 'LABEL_0', 'score': 0.9958921670913696},
#  {'label': 'LABEL_0', 'score': 0.9830297827720642},
#  {'label': 'LABEL_0', 'score': 0.9958653450012207},
#  {'label': 'LABEL_2', 'score': 0.952541708946228},
#  {'label': 'LABEL_2', 'score': 0.9846410155296326},
#  {'label': 'LABEL_2', 'score': 0.9680510759353638},
#  {'label': 'LABEL_0', 'score': 0.9938418865203857},
#  {'label': 'LABEL_0', 'score': 0.9879421591758728},
#  {'label': 'LABEL_1', 'score': 0.9580672383308411},
#  {'label': 'LABEL_0', 'score': 0.9699254631996155},
#  {'label': 'LABEL_0', 'score': 0.9954169988632202},
#  {'label': 'LABEL_0', 'score': 0.9106600880622864},
#  {'label': 'LABEL_2', 'score': 0.9905753135681152},
#  {'label': 'LABEL_0', 'score': 0.9877830147743225},
#  {'label': 'LABEL_0', 'score': 0.9889664053916931},
#  {'label': 'LABEL_2', 'score': 0.6999566555023193},
#  {'label': 'LABEL_1', 'score': 0.5686289668083191},
#  {'label': 'LABEL_2', 'score': 0.9794580936431885},
#  {'label': 'LABEL_0', 'score': 0.9158380627632141},
#  {'label': 'LABEL_0', 'score': 0.8263681530952454},
#  {'label': 'LABEL_0', 'score': 0.8993874192237854},
#  {'label': 'LABEL_0', 'score': 0.7141001224517822},
#  {'label': 'LABEL_0', 'score': 0.9937295913696289},
#  {'label': 'LABEL_2', 'score': 0.8918106555938721},
#  {'label': 'LABEL_0', 'score': 0.9957499504089355},
#  {'label': 'LABEL_0', 'score': 0.6996200680732727},
#  {'label': 'LABEL_1', 'score': 0.967695415019989},
#  {'label': 'LABEL_0', 'score': 0.9888762831687927},
#  {'label': 'LABEL_1', 'score': 0.9769993424415588},
#  {'label': 'LABEL_2', 'score': 0.9765470027923584},
#  {'label': 'LABEL_1', 'score': 0.9585490822792053},
#  {'label': 'LABEL_2', 'score': 0.5824701189994812},
#  {'label': 'LABEL_0', 'score': 0.9918632507324219},
#  {'label': 'LABEL_0', 'score': 0.8094878792762756},
#  {'label': 'LABEL_2', 'score': 0.9106315970420837},
#  {'label': 'LABEL_1', 'score': 0.7603881359100342},
#  {'label': 'LABEL_0', 'score': 0.86335688829422},
#  {'label': 'LABEL_0', 'score': 0.9937898516654968},
#  {'label': 'LABEL_0', 'score': 0.7007387280464172},
#  {'label': 'LABEL_1', 'score': 0.8466585278511047},
#  {'label': 'LABEL_2', 'score': 0.9864274859428406},
#  {'label': 'LABEL_0', 'score': 0.9942533373832703},
#  {'label': 'LABEL_2', 'score': 0.9901200532913208},
#  {'label': 'LABEL_2', 'score': 0.7291674017906189},
#  {'label': 'LABEL_1', 'score': 0.9134388566017151},
#  {'label': 'LABEL_0', 'score': 0.9712022542953491},
#  {'label': 'LABEL_0', 'score': 0.9951996803283691},
#  {'label': 'LABEL_0', 'score': 0.9915214776992798},
#  {'label': 'LABEL_0', 'score': 0.9761024713516235},
#  {'label': 'LABEL_1', 'score': 0.9348392486572266},
#  {'label': 'LABEL_0', 'score': 0.9943723678588867},
#  {'label': 'LABEL_1', 'score': 0.814001202583313},
#  {'label': 'LABEL_0', 'score': 0.9959571957588196},
#  {'label': 'LABEL_0', 'score': 0.9953171014785767},
#  {'label': 'LABEL_1', 'score': 0.9748629331588745},
#  {'label': 'LABEL_0', 'score': 0.8189424276351929},
#  {'label': 'LABEL_2', 'score': 0.9698771238327026},
#  {'label': 'LABEL_0', 'score': 0.9854562878608704},
#  {'label': 'LABEL_2', 'score': 0.6849930286407471},
#  {'label': 'LABEL_2', 'score': 0.9788708686828613},
#  {'label': 'LABEL_2', 'score': 0.9695622324943542},
#  {'label': 'LABEL_0', 'score': 0.9934762120246887},
#  {'label': 'LABEL_0', 'score': 0.9286117553710938},
#  {'label': 'LABEL_2', 'score': 0.9499052166938782},
#  {'label': 'LABEL_0', 'score': 0.9928408861160278},
#  {'label': 'LABEL_0', 'score': 0.9931436777114868},
#  {'label': 'LABEL_1', 'score': 0.5846609473228455},
#  {'label': 'LABEL_0', 'score': 0.8875654935836792},
#  {'label': 'LABEL_2', 'score': 0.5955909490585327},
#  {'label': 'LABEL_0', 'score': 0.8685852885246277},
#  {'label': 'LABEL_1', 'score': 0.9581626653671265},
#  {'label': 'LABEL_0', 'score': 0.9924877882003784},
#  {'label': 'LABEL_0', 'score': 0.9957375526428223},
#  {'label': 'LABEL_0', 'score': 0.9953795671463013},
#  {'label': 'LABEL_0', 'score': 0.9809962511062622},
#  {'label': 'LABEL_0', 'score': 0.9852697253227234},
#  {'label': 'LABEL_0', 'score': 0.9951691031455994},
#  {'label': 'LABEL_0', 'score': 0.9958919286727905},
#  {'label': 'LABEL_0', 'score': 0.9950106143951416},
#  {'label': 'LABEL_0', 'score': 0.9901621341705322},
#  {'label': 'LABEL_0', 'score': 0.9960987567901611},
#  {'label': 'LABEL_2', 'score': 0.9569994211196899},
#  {'label': 'LABEL_0', 'score': 0.9768708944320679},
#  {'label': 'LABEL_0', 'score': 0.9760960936546326},
#  {'label': 'LABEL_0', 'score': 0.9302232265472412},
#  {'label': 'LABEL_2', 'score': 0.6931226253509521},
#  {'label': 'LABEL_2', 'score': 0.7412242293357849},
#  {'label': 'LABEL_0', 'score': 0.9800959825515747},
#  {'label': 'LABEL_1', 'score': 0.822669506072998},
#  {'label': 'LABEL_0', 'score': 0.9519787430763245},
#  {'label': 'LABEL_0', 'score': 0.994868278503418},
#  {'label': 'LABEL_2', 'score': 0.9007478356361389},
#  {'label': 'LABEL_0', 'score': 0.9794227480888367},
#  {'label': 'LABEL_2', 'score': 0.9759052395820618},
#  {'label': 'LABEL_1', 'score': 0.9441781044006348},
#  {'label': 'LABEL_0', 'score': 0.7549024820327759},
#  {'label': 'LABEL_1', 'score': 0.8170261979103088},
#  {'label': 'LABEL_0', 'score': 0.7490110397338867},
#  {'label': 'LABEL_1', 'score': 0.7642605900764465},
#  {'label': 'LABEL_0', 'score': 0.9934532642364502},
#  {'label': 'LABEL_0', 'score': 0.85845547914505},
#  {'label': 'LABEL_0', 'score': 0.9947808384895325},
#  {'label': 'LABEL_1', 'score': 0.8712813258171082},
#  {'label': 'LABEL_0', 'score': 0.9927108287811279},
#  {'label': 'LABEL_2', 'score': 0.8834566473960876},
#  {'label': 'LABEL_0', 'score': 0.9951080679893494},
#  {'label': 'LABEL_0', 'score': 0.9478111267089844},
#  {'label': 'LABEL_0', 'score': 0.9792137742042542},
#  {'label': 'LABEL_0', 'score': 0.9945896863937378},
#  {'label': 'LABEL_1', 'score': 0.9374461770057678},
#  {'label': 'LABEL_0', 'score': 0.9933011531829834},
#  {'label': 'LABEL_0', 'score': 0.6094308495521545},
#  {'label': 'LABEL_2', 'score': 0.9735954999923706},
#  {'label': 'LABEL_0', 'score': 0.9896060228347778},
#  {'label': 'LABEL_0', 'score': 0.9929036498069763},
#  {'label': 'LABEL_0', 'score': 0.9817789793014526},
#  {'label': 'LABEL_0', 'score': 0.9953032732009888},
#  {'label': 'LABEL_0', 'score': 0.9954368472099304},
#  {'label': 'LABEL_0', 'score': 0.9951291084289551},
#  {'label': 'LABEL_1', 'score': 0.973620593547821},
#  {'label': 'LABEL_1', 'score': 0.8778523802757263},
#  {'label': 'LABEL_0', 'score': 0.922656774520874},
#  {'label': 'LABEL_0', 'score': 0.956291913986206},
#  {'label': 'LABEL_0', 'score': 0.9621592164039612},
#  {'label': 'LABEL_0', 'score': 0.9912205338478088},
#  {'label': 'LABEL_0', 'score': 0.990369975566864},
#  {'label': 'LABEL_0', 'score': 0.9955300688743591},
#  {'label': 'LABEL_1', 'score': 0.9528313279151917},
#  {'label': 'LABEL_0', 'score': 0.9130882024765015},
#  {'label': 'LABEL_0', 'score': 0.9867047071456909},
#  {'label': 'LABEL_1', 'score': 0.9740516543388367},
#  {'label': 'LABEL_0', 'score': 0.9382289052009583},
#  {'label': 'LABEL_0', 'score': 0.9012208580970764},
#  {'label': 'LABEL_0', 'score': 0.9958763122558594},
#  {'label': 'LABEL_0', 'score': 0.6578056216239929},
#  {'label': 'LABEL_1', 'score': 0.9228058457374573},
#  {'label': 'LABEL_0', 'score': 0.9881567358970642},
#  {'label': 'LABEL_2', 'score': 0.967982828617096},
#  {'label': 'LABEL_0', 'score': 0.9847365021705627},
#  {'label': 'LABEL_0', 'score': 0.9943543672561646},
#  {'label': 'LABEL_1', 'score': 0.9713438153266907},
#  {'label': 'LABEL_1', 'score': 0.9231359958648682},
#  {'label': 'LABEL_0', 'score': 0.819179892539978},
#  {'label': 'LABEL_0', 'score': 0.9521653056144714},
#  {'label': 'LABEL_0', 'score': 0.9941668510437012},
#  {'label': 'LABEL_2', 'score': 0.9743513464927673},
#  {'label': 'LABEL_1', 'score': 0.8943553566932678},
#  {'label': 'LABEL_2', 'score': 0.9583169221878052},
#  {'label': 'LABEL_0', 'score': 0.9928769469261169},
#  {'label': 'LABEL_2', 'score': 0.9280442595481873},
#  {'label': 'LABEL_2', 'score': 0.9116708636283875},
#  {'label': 'LABEL_2', 'score': 0.9443376660346985},
#  {'label': 'LABEL_0', 'score': 0.6769692897796631},
#  {'label': 'LABEL_0', 'score': 0.9789419174194336},
#  {'label': 'LABEL_0', 'score': 0.9565927982330322},
#  {'label': 'LABEL_0', 'score': 0.9945912957191467},
#  {'label': 'LABEL_0', 'score': 0.9842655658721924},
#  {'label': 'LABEL_0', 'score': 0.994066596031189},
#  {'label': 'LABEL_2', 'score': 0.8100981116294861},
#  {'label': 'LABEL_0', 'score': 0.9926630258560181},
#  {'label': 'LABEL_0', 'score': 0.9908726811408997},
#  {'label': 'LABEL_2', 'score': 0.9157792925834656},
#  {'label': 'LABEL_0', 'score': 0.9870179295539856},
#  {'label': 'LABEL_0', 'score': 0.9950869679450989},
#  {'label': 'LABEL_1', 'score': 0.8326239585876465},
#  {'label': 'LABEL_0', 'score': 0.9585703015327454},
#  {'label': 'LABEL_0', 'score': 0.9376325011253357},
#  {'label': 'LABEL_2', 'score': 0.9893704652786255},
#  {'label': 'LABEL_2', 'score': 0.4851820170879364},
#  {'label': 'LABEL_0', 'score': 0.9956102967262268},
#  {'label': 'LABEL_1', 'score': 0.4913865923881531},
#  {'label': 'LABEL_0', 'score': 0.9935664534568787},
#  {'label': 'LABEL_0', 'score': 0.9903790950775146},
#  {'label': 'LABEL_0', 'score': 0.989879846572876},
#  {'label': 'LABEL_0', 'score': 0.9950305223464966},
#  {'label': 'LABEL_0', 'score': 0.9815115332603455},
#  {'label': 'LABEL_2', 'score': 0.9891439080238342},
#  {'label': 'LABEL_1', 'score': 0.9684938192367554},
#  {'label': 'LABEL_0', 'score': 0.5193789601325989},
#  {'label': 'LABEL_0', 'score': 0.9752861857414246},
#  {'label': 'LABEL_0', 'score': 0.9890641570091248},
#  {'label': 'LABEL_2', 'score': 0.6850720643997192},
#  {'label': 'LABEL_2', 'score': 0.9857843518257141},
#  {'label': 'LABEL_0', 'score': 0.9751571416854858},
#  {'label': 'LABEL_2', 'score': 0.9771550297737122},
#  {'label': 'LABEL_1', 'score': 0.6253734230995178},
#  {'label': 'LABEL_2', 'score': 0.9831255078315735},
#  {'label': 'LABEL_0', 'score': 0.9897357225418091},
#  {'label': 'LABEL_0', 'score': 0.9802842736244202},
#  {'label': 'LABEL_0', 'score': 0.9919582605361938},
#  {'label': 'LABEL_0', 'score': 0.9922752976417542},
#  {'label': 'LABEL_2', 'score': 0.855893075466156},
#  {'label': 'LABEL_0', 'score': 0.9862502813339233},
#  {'label': 'LABEL_2', 'score': 0.9581470489501953},
#  {'label': 'LABEL_2', 'score': 0.5075851082801819},
#  {'label': 'LABEL_1', 'score': 0.703923225402832},
#  {'label': 'LABEL_0', 'score': 0.9957934617996216},
#  {'label': 'LABEL_0', 'score': 0.9944571256637573},
#  {'label': 'LABEL_2', 'score': 0.8560202121734619},
#  {'label': 'LABEL_2', 'score': 0.5962426066398621},
#  {'label': 'LABEL_2', 'score': 0.9872919321060181},
#  {'label': 'LABEL_0', 'score': 0.9950287938117981},
#  {'label': 'LABEL_0', 'score': 0.8734370470046997},
#  {'label': 'LABEL_0', 'score': 0.9933944344520569},
#  {'label': 'LABEL_0', 'score': 0.9921363592147827},
#  {'label': 'LABEL_0', 'score': 0.9959623217582703},
#  {'label': 'LABEL_2', 'score': 0.9521074295043945},
#  {'label': 'LABEL_0', 'score': 0.9882611632347107},
#  {'label': 'LABEL_0', 'score': 0.901297390460968},
#  {'label': 'LABEL_1', 'score': 0.9377819895744324},
#  {'label': 'LABEL_0', 'score': 0.9810317158699036},
#  {'label': 'LABEL_0', 'score': 0.9854320883750916},
#  {'label': 'LABEL_0', 'score': 0.9817490577697754},
#  {'label': 'LABEL_0', 'score': 0.9954138398170471},
#  {'label': 'LABEL_2', 'score': 0.9793749451637268},
#  {'label': 'LABEL_1', 'score': 0.9619709849357605},
#  {'label': 'LABEL_2', 'score': 0.9644289612770081},
#  {'label': 'LABEL_1', 'score': 0.9464492797851562},
#  {'label': 'LABEL_0', 'score': 0.9797057509422302},
#  {'label': 'LABEL_0', 'score': 0.9958639144897461},
#  {'label': 'LABEL_2', 'score': 0.7975776791572571},
#  {'label': 'LABEL_0', 'score': 0.9641682505607605},
#  {'label': 'LABEL_0', 'score': 0.9896685481071472},
#  {'label': 'LABEL_1', 'score': 0.9767826199531555},
#  {'label': 'LABEL_0', 'score': 0.9942469596862793},
#  {'label': 'LABEL_0', 'score': 0.9936373233795166},
#  {'label': 'LABEL_0', 'score': 0.9301437139511108},
#  {'label': 'LABEL_1', 'score': 0.6375629901885986},
#  {'label': 'LABEL_0', 'score': 0.9909165501594543},
#  {'label': 'LABEL_0', 'score': 0.9950445890426636},
#  {'label': 'LABEL_2', 'score': 0.9793074131011963},
#  {'label': 'LABEL_1', 'score': 0.9501903057098389},
#  {'label': 'LABEL_0', 'score': 0.993303120136261},
#  {'label': 'LABEL_0', 'score': 0.942278265953064},
#  {'label': 'LABEL_0', 'score': 0.8345712423324585},
#  {'label': 'LABEL_2', 'score': 0.96834397315979},
#  {'label': 'LABEL_0', 'score': 0.9792571067810059},
#  {'label': 'LABEL_0', 'score': 0.8785452246665955},
#  {'label': 'LABEL_0', 'score': 0.9188022017478943},
#  {'label': 'LABEL_0', 'score': 0.9925327897071838},
#  {'label': 'LABEL_2', 'score': 0.6703032851219177},
#  {'label': 'LABEL_1', 'score': 0.9493175148963928},
#  {'label': 'LABEL_2', 'score': 0.951440155506134},
#  {'label': 'LABEL_0', 'score': 0.9890257716178894},
#  {'label': 'LABEL_0', 'score': 0.9941205382347107},
#  {'label': 'LABEL_2', 'score': 0.6730773448944092},
#  {'label': 'LABEL_0', 'score': 0.9946962594985962},
#  {'label': 'LABEL_0', 'score': 0.9921578168869019},
#  {'label': 'LABEL_0', 'score': 0.9894058108329773},
#  {'label': 'LABEL_2', 'score': 0.4255659580230713},
#  {'label': 'LABEL_2', 'score': 0.9525018930435181},
#  {'label': 'LABEL_2', 'score': 0.9175254702568054},
#  {'label': 'LABEL_0', 'score': 0.988203227519989},
#  {'label': 'LABEL_2', 'score': 0.9644898176193237},
#  {'label': 'LABEL_2', 'score': 0.6732736825942993},
#  {'label': 'LABEL_0', 'score': 0.9819627404212952},
#  {'label': 'LABEL_0', 'score': 0.9930223822593689},
#  {'label': 'LABEL_0', 'score': 0.9958868622779846},
#  {'label': 'LABEL_0', 'score': 0.9953749775886536},
#  {'label': 'LABEL_2', 'score': 0.7599443793296814},
#  {'label': 'LABEL_2', 'score': 0.9098785519599915},
#  {'label': 'LABEL_0', 'score': 0.9932324886322021},
#  {'label': 'LABEL_0', 'score': 0.9880926012992859},
#  {'label': 'LABEL_0', 'score': 0.9612907767295837},
#  {'label': 'LABEL_2', 'score': 0.9355420470237732},
#  {'label': 'LABEL_0', 'score': 0.9765440225601196},
#  {'label': 'LABEL_2', 'score': 0.9642853736877441},
#  {'label': 'LABEL_0', 'score': 0.9932146072387695},
#  {'label': 'LABEL_0', 'score': 0.5764611959457397},
#  {'label': 'LABEL_0', 'score': 0.9933748841285706},
#  {'label': 'LABEL_0', 'score': 0.9741997718811035},
#  {'label': 'LABEL_0', 'score': 0.7628687620162964},
#  {'label': 'LABEL_1', 'score': 0.957994818687439},
#  {'label': 'LABEL_0', 'score': 0.9101030230522156},
#  {'label': 'LABEL_0', 'score': 0.5955782532691956},
#  {'label': 'LABEL_1', 'score': 0.9593653082847595},
#  {'label': 'LABEL_2', 'score': 0.9828822612762451},
#  {'label': 'LABEL_0', 'score': 0.9933242201805115},
#  {'label': 'LABEL_0', 'score': 0.993772566318512},
#  {'label': 'LABEL_0', 'score': 0.6168062686920166},
#  {'label': 'LABEL_0', 'score': 0.9962360262870789},
#  {'label': 'LABEL_0', 'score': 0.9826326370239258},
#  {'label': 'LABEL_0', 'score': 0.9935812950134277},
#  {'label': 'LABEL_0', 'score': 0.9849575757980347},
#  {'label': 'LABEL_0', 'score': 0.9951582551002502},
#  {'label': 'LABEL_0', 'score': 0.9945693016052246},
#  {'label': 'LABEL_2', 'score': 0.970983624458313},
#  {'label': 'LABEL_2', 'score': 0.4706064462661743},
#  {'label': 'LABEL_2', 'score': 0.9636083841323853},
#  {'label': 'LABEL_0', 'score': 0.9870598316192627},
#  {'label': 'LABEL_2', 'score': 0.6599038243293762},
#  {'label': 'LABEL_0', 'score': 0.9955806136131287},
#  {'label': 'LABEL_0', 'score': 0.9883211255073547},
#  {'label': 'LABEL_0', 'score': 0.9866237044334412},
#  {'label': 'LABEL_0', 'score': 0.9910373687744141},
#  {'label': 'LABEL_2', 'score': 0.8765683770179749},
#  {'label': 'LABEL_0', 'score': 0.98348468542099},
#  {'label': 'LABEL_0', 'score': 0.9447714686393738},
#  {'label': 'LABEL_2', 'score': 0.8204482197761536},
#  {'label': 'LABEL_2', 'score': 0.8833885192871094},
#  {'label': 'LABEL_2', 'score': 0.9804609417915344},
#  {'label': 'LABEL_1', 'score': 0.9522367715835571},
#  {'label': 'LABEL_0', 'score': 0.9183128476142883},
#  {'label': 'LABEL_1', 'score': 0.9646430015563965},
#  {'label': 'LABEL_1', 'score': 0.9540567398071289},
#  {'label': 'LABEL_1', 'score': 0.5939272046089172},
#  {'label': 'LABEL_0', 'score': 0.747893214225769},
#  {'label': 'LABEL_0', 'score': 0.569773256778717},
#  {'label': 'LABEL_0', 'score': 0.9953799247741699},
#  {'label': 'LABEL_0', 'score': 0.9951706528663635},
#  {'label': 'LABEL_0', 'score': 0.994544267654419},
#  {'label': 'LABEL_1', 'score': 0.786034345626831},
#  {'label': 'LABEL_1', 'score': 0.9782134890556335},
#  {'label': 'LABEL_0', 'score': 0.9930562376976013},
#  {'label': 'LABEL_0', 'score': 0.9412909746170044},
#  {'label': 'LABEL_0', 'score': 0.984302282333374},
#  {'label': 'LABEL_0', 'score': 0.9921835064888},
#  {'label': 'LABEL_2', 'score': 0.8985919952392578},
#  {'label': 'LABEL_1', 'score': 0.9404733777046204},
#  {'label': 'LABEL_0', 'score': 0.7603666186332703},
#  {'label': 'LABEL_2', 'score': 0.5326262712478638},
#  {'label': 'LABEL_0', 'score': 0.9448699951171875},
#  {'label': 'LABEL_0', 'score': 0.995044469833374},
#  {'label': 'LABEL_0', 'score': 0.9690495133399963},
#  {'label': 'LABEL_0', 'score': 0.7604727149009705},
#  {'label': 'LABEL_0', 'score': 0.9715495109558105},
#  {'label': 'LABEL_0', 'score': 0.990841269493103},
#  {'label': 'LABEL_1', 'score': 0.9760966897010803},
#  {'label': 'LABEL_1', 'score': 0.5894344449043274},
#  {'label': 'LABEL_0', 'score': 0.9756579995155334},
#  {'label': 'LABEL_2', 'score': 0.8299853801727295},
#  {'label': 'LABEL_0', 'score': 0.713575005531311},
#  {'label': 'LABEL_0', 'score': 0.9803943634033203},
#  {'label': 'LABEL_0', 'score': 0.764647364616394},
#  {'label': 'LABEL_0', 'score': 0.6198460459709167},
#  {'label': 'LABEL_0', 'score': 0.9923378825187683},
#  {'label': 'LABEL_0', 'score': 0.9482057094573975},
#  {'label': 'LABEL_0', 'score': 0.9588508009910583},
#  {'label': 'LABEL_0', 'score': 0.6961244344711304},
#  {'label': 'LABEL_0', 'score': 0.9950994849205017},
#  {'label': 'LABEL_1', 'score': 0.7641239762306213},
#  {'label': 'LABEL_0', 'score': 0.9759364128112793},
#  {'label': 'LABEL_0', 'score': 0.9882596731185913},
#  {'label': 'LABEL_0', 'score': 0.9919005632400513},
#  {'label': 'LABEL_1', 'score': 0.5903987288475037},
#  {'label': 'LABEL_0', 'score': 0.8636171817779541},
#  {'label': 'LABEL_0', 'score': 0.9870617985725403},
#  {'label': 'LABEL_2', 'score': 0.47573453187942505},
#  {'label': 'LABEL_0', 'score': 0.9343104362487793},
#  {'label': 'LABEL_0', 'score': 0.9732491970062256},
#  {'label': 'LABEL_2', 'score': 0.9279532432556152},
#  {'label': 'LABEL_2', 'score': 0.982580840587616},
#  {'label': 'LABEL_0', 'score': 0.9913409352302551},
#  {'label': 'LABEL_0', 'score': 0.9634664058685303},
#  {'label': 'LABEL_0', 'score': 0.6630652546882629},
#  {'label': 'LABEL_1', 'score': 0.9820897579193115},
#  {'label': 'LABEL_0', 'score': 0.8839958310127258},
#  {'label': 'LABEL_0', 'score': 0.9067893028259277},
#  {'label': 'LABEL_2', 'score': 0.8382698893547058},
#  {'label': 'LABEL_0', 'score': 0.9944568872451782},
#  {'label': 'LABEL_0', 'score': 0.9910150170326233},
#  {'label': 'LABEL_0', 'score': 0.9906298518180847},
#  {'label': 'LABEL_0', 'score': 0.9959107637405396},
#  {'label': 'LABEL_2', 'score': 0.6519646048545837},
#  {'label': 'LABEL_0', 'score': 0.9805229306221008},
#  {'label': 'LABEL_0', 'score': 0.9952338337898254},
#  {'label': 'LABEL_1', 'score': 0.9310743808746338},
#  {'label': 'LABEL_0', 'score': 0.9948175549507141},
#  {'label': 'LABEL_2', 'score': 0.5349802374839783},
#  {'label': 'LABEL_0', 'score': 0.9489660263061523},
#  {'label': 'LABEL_0', 'score': 0.9810683131217957},
#  {'label': 'LABEL_2', 'score': 0.9866260886192322},
#  {'label': 'LABEL_1', 'score': 0.982884407043457},
#  {'label': 'LABEL_2', 'score': 0.9876465797424316},
#  {'label': 'LABEL_1', 'score': 0.6678032279014587},
#  {'label': 'LABEL_2', 'score': 0.7009856700897217},
#  {'label': 'LABEL_2', 'score': 0.9376674294471741},
#  {'label': 'LABEL_1', 'score': 0.8992810845375061},
#  {'label': 'LABEL_0', 'score': 0.9952875375747681},
#  {'label': 'LABEL_2', 'score': 0.9525588154792786},
#  {'label': 'LABEL_2', 'score': 0.9478452801704407},
#  {'label': 'LABEL_0', 'score': 0.9789414405822754},
#  {'label': 'LABEL_0', 'score': 0.7565416097640991},
#  {'label': 'LABEL_0', 'score': 0.9940991401672363},
#  {'label': 'LABEL_2', 'score': 0.9566304087638855},
#  {'label': 'LABEL_0', 'score': 0.9945265650749207},
#  {'label': 'LABEL_2', 'score': 0.9068171381950378},
#  {'label': 'LABEL_1', 'score': 0.8112959861755371},
#  {'label': 'LABEL_0', 'score': 0.9939762353897095},
#  {'label': 'LABEL_2', 'score': 0.5626717805862427},
#  {'label': 'LABEL_0', 'score': 0.9943682551383972},
#  {'label': 'LABEL_0', 'score': 0.9963024854660034},
#  {'label': 'LABEL_2', 'score': 0.9894043207168579},
#  {'label': 'LABEL_2', 'score': 0.7854481935501099},
#  {'label': 'LABEL_2', 'score': 0.831009566783905},
#  {'label': 'LABEL_0', 'score': 0.9866122007369995},
#  {'label': 'LABEL_0', 'score': 0.9902104139328003},
#  {'label': 'LABEL_0', 'score': 0.9926607608795166},
#  {'label': 'LABEL_1', 'score': 0.9663121700286865},
#  {'label': 'LABEL_1', 'score': 0.9318786859512329},
#  {'label': 'LABEL_0', 'score': 0.9912264943122864},
#  {'label': 'LABEL_1', 'score': 0.6090295314788818},
#  {'label': 'LABEL_2', 'score': 0.9877610206604004},
#  {'label': 'LABEL_2', 'score': 0.7442226409912109},
#  {'label': 'LABEL_0', 'score': 0.9941465854644775},
#  {'label': 'LABEL_0', 'score': 0.977696418762207},
#  {'label': 'LABEL_2', 'score': 0.9608563184738159},
#  {'label': 'LABEL_1', 'score': 0.9424600601196289},
#  {'label': 'LABEL_0', 'score': 0.9938643574714661},
#  {'label': 'LABEL_0', 'score': 0.9949617385864258},
#  {'label': 'LABEL_0', 'score': 0.9952334761619568},
#  {'label': 'LABEL_1', 'score': 0.9819599390029907},
#  {'label': 'LABEL_2', 'score': 0.9702275991439819},
#  {'label': 'LABEL_0', 'score': 0.9957352876663208},
#  {'label': 'LABEL_0', 'score': 0.991847038269043},
#  {'label': 'LABEL_0', 'score': 0.9922027587890625},
#  {'label': 'LABEL_0', 'score': 0.9852465391159058},
#  {'label': 'LABEL_0', 'score': 0.9784665703773499},
#  {'label': 'LABEL_0', 'score': 0.9918489456176758},
#  {'label': 'LABEL_2', 'score': 0.9466519951820374},
#  {'label': 'LABEL_1', 'score': 0.9664177894592285},
#  {'label': 'LABEL_0', 'score': 0.9094903469085693},
#  {'label': 'LABEL_0', 'score': 0.9640593528747559},
#  {'label': 'LABEL_0', 'score': 0.9948500990867615},
#  {'label': 'LABEL_0', 'score': 0.9783299565315247},
#  {'label': 'LABEL_2', 'score': 0.9896261692047119},
#  {'label': 'LABEL_0', 'score': 0.6065468192100525},
#  {'label': 'LABEL_1', 'score': 0.8834846615791321},
#  {'label': 'LABEL_0', 'score': 0.9922286868095398},
#  {'label': 'LABEL_0', 'score': 0.7156449556350708},
#  {'label': 'LABEL_1', 'score': 0.8096543550491333},
#  {'label': 'LABEL_0', 'score': 0.9952083230018616},
#  {'label': 'LABEL_1', 'score': 0.9415973424911499},
#  {'label': 'LABEL_0', 'score': 0.9959728121757507},
#  {'label': 'LABEL_0', 'score': 0.9954273700714111},
#  {'label': 'LABEL_0', 'score': 0.9958093166351318},
#  {'label': 'LABEL_0', 'score': 0.9950114488601685},
#  {'label': 'LABEL_0', 'score': 0.6430943608283997},
#  {'label': 'LABEL_1', 'score': 0.9855496287345886},
#  {'label': 'LABEL_2', 'score': 0.9594659805297852},
#  {'label': 'LABEL_0', 'score': 0.8802968859672546},
#  {'label': 'LABEL_0', 'score': 0.9893263578414917},
#  {'label': 'LABEL_0', 'score': 0.9944309592247009},
#  {'label': 'LABEL_2', 'score': 0.5530650019645691},
#  {'label': 'LABEL_0', 'score': 0.9921370148658752},
#  {'label': 'LABEL_0', 'score': 0.9940661191940308},
#  {'label': 'LABEL_0', 'score': 0.9950002431869507},
#  {'label': 'LABEL_0', 'score': 0.9837722182273865},
#  {'label': 'LABEL_0', 'score': 0.9910586476325989},
#  {'label': 'LABEL_2', 'score': 0.9916526675224304},
#  {'label': 'LABEL_1', 'score': 0.530095636844635},
#  {'label': 'LABEL_0', 'score': 0.9771174192428589},
#  {'label': 'LABEL_1', 'score': 0.5791877508163452},
#  {'label': 'LABEL_0', 'score': 0.7386305332183838},
#  {'label': 'LABEL_0', 'score': 0.9914814233779907},
#  {'label': 'LABEL_2', 'score': 0.8718019127845764},
#  {'label': 'LABEL_0', 'score': 0.9957218170166016},
#  {'label': 'LABEL_0', 'score': 0.9263466596603394},
#  {'label': 'LABEL_0', 'score': 0.9715718626976013},
#  {'label': 'LABEL_1', 'score': 0.9618008732795715},
#  {'label': 'LABEL_0', 'score': 0.9875901937484741},
#  {'label': 'LABEL_0', 'score': 0.9947385191917419},
#  {'label': 'LABEL_0', 'score': 0.9927075505256653},
#  {'label': 'LABEL_1', 'score': 0.9393901228904724},
#  {'label': 'LABEL_0', 'score': 0.9422236680984497},
#  {'label': 'LABEL_1', 'score': 0.9728561639785767},
#  {'label': 'LABEL_0', 'score': 0.9951286315917969},
#  {'label': 'LABEL_0', 'score': 0.487120121717453},
#  {'label': 'LABEL_0', 'score': 0.9900257587432861},
#  {'label': 'LABEL_2', 'score': 0.9903523325920105},
#  {'label': 'LABEL_0', 'score': 0.9923790693283081},
#  {'label': 'LABEL_0', 'score': 0.9953372478485107},
#  {'label': 'LABEL_2', 'score': 0.9475551247596741},
#  {'label': 'LABEL_0', 'score': 0.9779613018035889},
#  {'label': 'LABEL_0', 'score': 0.9888960123062134},
#  {'label': 'LABEL_0', 'score': 0.9958274960517883},
#  {'label': 'LABEL_1', 'score': 0.9770569205284119},
#  {'label': 'LABEL_0', 'score': 0.9932768940925598},
#  {'label': 'LABEL_0', 'score': 0.9088464975357056},
#  {'label': 'LABEL_0', 'score': 0.9872145652770996},
#  {'label': 'LABEL_0', 'score': 0.5660938620567322},
#  ...]

# %%
# we wanna convert the dictionary above into an integer label then call this function for
#every item in our predictions list to convert integers to a list of integer labels
def get_label(d):
  return int(d["label"].split('_')[1])
test_pred=[get_label(d) for d in test_pred]

# %%
print("acc:",accuracy_score(split['test']["label"],test_pred))
# Out:
# acc: 0.8346994535519126

# %%
print("f1:", f1_score(split["test"]["label"],test_pred,average="macro"))
# Out:
# f1: 0.7869374680732628

# %% [markdown]
# since f1 is lower thsn accuracy it can be an ubnalance in the dataset

# %%
#this was a n inbalanced dataset so we would like to see if it is performing better on one class compare to others
#since f1 score is less than accuracy , we can be certain ther is an unbalance on how the model perform on each class
# when the target in nuetral we do not do well in predicting that is nuetral
def plot_cm(cm):
  classes=['negative', 'positive','neutral']
  df_cm=pd.DataFrame(cm,index=classes, columns=classes)
  ax= sn.heatmap(df_cm,annot=True,fmt='g')
  ax.set_xlabel("predicted")
  ax.set_ylabel("Target")

cm=confusion_matrix(split['test']['label'], test_pred, normalize='true')
plot_cm(cm)

# %% [markdown]
# * when the target is negative we do very well predicting negative(0.89)
# * when the target is nuetral we do not do well on predicting(0.71) instead we incorrectly predict that a lot of those tweets were negative (0.21)
# *  when the target is positive, predictions seem to be evenly split among the negative an positive
