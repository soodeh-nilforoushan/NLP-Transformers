# %% [markdown]
# <a href="https://colab.research.google.com/github/soodeh-nilforoushan/NLP-Transformers/blob/main/QuestionAnswering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **QuestionAnswering**: we wanna have a system that answer all of the questions.
#
#
# *   one of the standard question answering benchmark datsets is SQuAD(stanford question answering dataset)
#
# *  squad is an extractive Q A dataset.
# extractive means input contains both question and the answer, and all the model has to do is choose the right part of the input.
#
#
# *   large language models are pre-trained using very simple inputs and outputs like trying to predict the next word in a sentence. so duringht e pre train the nueral network never seed very complex such as context in question pairing. and during the fine tuning process the model learns how to interpret what it means

# %%
# !pip install transformers
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 13.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 24.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 29.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 41.8 MB/s eta 0:00:00
# ...

# %%
from transformers import pipeline

# %%
qa=pipeline("question-answering")
# Out:
# No model was supplied, defaulted to distilbert-base-cased-distilled-squad and revision 626af31 (https://huggingface.co/distilbert-base-cased-distilled-squad).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# ...
# No CUDA runtime is found, using CUDA_HOME='/usr/local/cuda'

# %%
context="Today I went to the store to purchuse a carton of milk."
question="what did I buy?"

# %%
qa(context=context, question=question)
# Out:
# {'score': 0.7131171822547913, 'start': 50, 'end': 54, 'answer': 'milk'}

# %%
context[38:54]
# Out:
# 'a carton of milk'
